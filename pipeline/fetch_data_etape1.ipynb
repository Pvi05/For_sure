# %%
from atproto import Client
import os

# 1. Connexion (L'auth n'est pas tjs requise pour la lecture publique,
# mais recommandée pour éviter les limites de débit)
client = Client()
# client.login('ton-handle.bsky.social', 'ton-mot-de-passe-app')

def track_post_info(post_uri):
    """
    Analyse les informations d'un post Bluesky et ses interactions
    """
    try:
        # Récupérer le thread (le post + les réponses)
        # depth=10 permet de descendre profondément dans l'arbre des réponses
        thread = client.get_post_thread(uri=post_uri, depth=10)
        
        post_data = thread.thread.post
        
        print(f"--- ANALYSE DU POST ---")
        print(f"Auteur: {post_data.author.handle}")
        print(f"Texte: {post_data.record.text}")
        print(f"Stats: {post_data.like_count} likes, {post_data.repost_count} reposts")
        
        # 2. Récupérer les gens qui ont reposté (les "vecteurs" de propagation)
        # Utiliser l'API Bluesky correctement
        try:
            reposts_response = client.app.bsky.feed.get_reposted_by({
                'uri': post_data.uri,
                'limit': 100  # Récupérer jusqu'à 100 profils
            })
            
            # Accéder à la liste des profils via 'reposted_by'
            reposted_by_list = reposts_response.reposted_by
            
            print(f"\n--- PROPAGATEURS (REPOSTS) - {len(reposted_by_list)} trouvés ---")
            if reposted_by_list:
                for profile in reposted_by_list:
                    display_name = profile.display_name if hasattr(profile, 'display_name') and profile.display_name else 'Sans nom'
                    followers = profile.followers_count if hasattr(profile, 'followers_count') else 'N/A'
                    print(f"- @{profile.handle} ({display_name}) - {followers} followers")
            else:
                print("Aucun repost trouvé")
        except Exception as repost_error:
            print(f"\n--- PROPAGATEURS (REPOSTS) ---")
            print(f"Erreur lors de la récupération: {repost_error}")
        
        # 3. Récupérer les réponses (le graphe de discussion)
        if hasattr(thread.thread, 'replies') and thread.thread.replies:
            print(f"\n--- RÉPONSES DIRECTES ---")
            for reply in thread.thread.replies:
                print(f"- De {reply.post.author.handle}: {reply.post.record.text[:50]}...")
        else:
            print("\nAucune réponse directe")
            
    except Exception as e:
        print(f"Erreur lors de la récupération du post: {e}")
        import traceback
        traceback.print_exc()

# Exemple d'utilisation avec un URI de post valide
# track_post_info('at://did:plc:z72i7hdynmk6r22z27h6tvur/app.bsky.feed.post/3lb6v...')

# %%
# Test avec le lien fourni
# L'authentification est requise pour pouvoir interroger les profils

# IMPORTANT: Pour fonctionner, vous devez vous authentifier
# Créez un "App Password" dans vos paramètres Bluesky si vous n'en avez pas

# Étape 1: Authentification
# Priorité : variable d'environnement > valeur par défaut codée en dur
HANDLE = os.getenv("BSKY_HANDLE", "for-sure.bsky.social")
APP_PASSWORD = os.getenv("BSKY_APP_PASSWORD", "LFfqA_n..7kz9KZ")

try:
    client.login(HANDLE, APP_PASSWORD)
    print(f"✓ Authentification réussie en tant que: {HANDLE}\n")
except Exception as e:
    print(f"✗ Erreur d'authentification: {e}")
    print("\nInstructions:")
    print("1. Remplissez HANDLE et APP_PASSWORD ci-dessus avec vos credentials")
    print("2. Créez un App Password dans: https://bsky.app/settings/app-passwords")
    print("3. Réexécutez cette cellule\n")

# Étape 2: Traitement du lien
def bsky_url_to_uri(url):
    """
    Convertit une URL Bluesky en URI AT valide
    Exemple: https://bsky.app/profile/mathieuhourdin.bsky.social/post/3mfetst7zbc2z
    """
    try:
        parts = url.split('/')
        handle = parts[4]  # mathieuhourdin.bsky.social
        post_id = parts[6]  # 3mfetst7zbc2z
        
        # Chercher le profil via search
        search_result = client.app.bsky.actor.search_actors({'term': handle})
        
        if search_result.actors:
            for actor in search_result.actors:
                if actor.handle == handle:
                    did = actor.did
                    uri = f"at://{did}/app.bsky.feed.post/{post_id}"
                    return uri
        
        return None
        
    except Exception as e:
        print(f"Erreur: {e}")
        return None

# Exécuter avec le lien fourni
bsky_url = "https://bsky.app/profile/mathieuhourdin.bsky.social/post/3mfetst7zbc2z"
print(f"Traitement de l'URL: {bsky_url}\n")
post_uri = bsky_url_to_uri(bsky_url)

if post_uri:
    print(f"✓ URI AT généré: {post_uri}\n")
    print("=== RÉSULTATS ===\n")
    track_post_info(post_uri)
else:
    print("✗ Impossible de générer l'URI AT")
# Out:
# ✓ Authentification réussie en tant que: for-sure.bsky.social
#
# Traitement de l'URL: https://bsky.app/profile/mathieuhourdin.bsky.social/post/3mfetst7zbc2z
#
# ✓ URI AT généré: at://did:plc:jyszdkkd7q4ejj4mah36jgde/app.bsky.feed.post/3mfetst7zbc2z
#
# === RÉSULTATS ===
#
# --- ANALYSE DU POST ---
# Auteur: mathieuhourdin.bsky.social
# Texte: Bravo au journaliste de bfm sur place, qui répète à chaque fois qu'il prend la parole que les participants au rassemblement de Lyon essaient de masquer leur appartenance mais qu'il voit des croix gammées etc et que c'est des néonazis
# Stats: 397 likes, 120 reposts
#
# --- PROPAGATEURS (REPOSTS) - 100 trouvés ---
# - @vincureuil.bsky.social (VincEcureuil) - N/A followers
# - @muzahara3nour.bsky.social (Sans nom) - N/A followers
# - @mikelkanik.bsky.social (Mikel K.) - N/A followers
# - @legrand1775.bsky.social (Sans nom) - N/A followers
# - @jeanlouv.bsky.social (jeanlouv) - N/A followers
# - @noguesp.bsky.social (Nogues) - N/A followers
# - @gorekhaa.bsky.social ([G.R.K.]©️😷👽🏴🏳️‍🌈🏳️‍⚧️Ⓐ💣🌏🌀 Your Daily Fix of Virtuous Sedition) - N/A followers
# - @jean-izdeguerlasse.bsky.social (Jean-Isidore de Guerlasse) - N/A followers
# - @valeria44.bsky.social (Valeria) - N/A followers
# - @sbwaraba24.bsky.social (SBecq24) - N/A followers
# - @nfredp.bsky.social (Sans nom) - N/A followers
# - @reradotage.bsky.social (Radotage) - N/A followers
# - @docquantique.bsky.social (Doc Quantique) - N/A followers
# - @pyg.enchenia.com (Pygargue Pirate - Arc Examens ! ピガ-ルグ !🍙🗾⛩️👺) - N/A followers
# - @jackm22.bsky.social (Oompaloompa) - N/A followers
# - @rosalouette.bsky.social (Rosa🌸Louette🔻) - N/A followers
# - @insoumisbreton.bsky.social (Cœur insoumis et breton) - N/A followers
# - @nbuchon.me (mantraktor ❄️🌧️) - N/A followers
# - @cathcrate.bsky.social (Cath🐜) - N/A followers
# - @abies77.bsky.social (Arno roule sa bosse à Clermont-Fd (ô-Tô)) - N/A followers
# - @cgirardon.bsky.social (Clément Girardon) - N/A followers
# - @emilywolf.bsky.social (Emily Wolf) - N/A followers
# - @pacooh-03.bsky.social (Sans nom) - N/A followers
# - @papableu.bsky.social (Sans nom) - N/A followers
# - @buenococo.bsky.social (Bueno Coco) - N/A followers
# - @nicogeo.bsky.social (Nico) - N/A followers
# - @zabou.bsky.social (ZabouVillon ) - N/A followers
# - @valerie-maltot.bsky.social (Sans nom) - N/A followers
# - @giomz.bsky.social (GiomZ) - N/A followers
# - @deizmat-58.bsky.social (Sans nom) - N/A followers
# - @vdsvt.bsky.social (Valérie Degoy) - N/A followers
# - @loulouleconquerant.bsky.social (Sans nom) - N/A followers
# - @anouchka.bsky.social (Anouchka) - N/A followers
# - @sly-tolosa.bsky.social (Sly Tolosa) - N/A followers
# - @bespierre.bsky.social (Bespierre) - N/A followers
# - @disana.bsky.social (Nicoleo) - N/A followers
# - @snoopy21.bsky.social (Catherine Marlier 🐶🐱🐈🐕) - N/A followers
# - @pari-banou.bsky.social (Pari) - N/A followers
# - @zoemocel.bsky.social (Sans nom) - N/A followers
# - @occitan10.bsky.social (L'Etat de fumier) - N/A followers
# - @inachiveg.bsky.social (Sans nom) - N/A followers
# - @colpizen.bsky.social (Colpizen) - N/A followers
# - @nathwoodcroft.ironstar.org (Athanil) - N/A followers
# - @ennemiinterieur.bsky.social (Exil intérieur🖕) - N/A followers
# - @lopezthe.bsky.social (LopezThe) - N/A followers
# - @crevekino.bsky.social (Gingembre O'Crevek) - N/A followers
# - @lezarap.bsky.social (Sans nom) - N/A followers
# - @seigneurao.com (Ao) - N/A followers
# - @motherfeur.bsky.social (Little mushroom) - N/A followers
# - @gingerbreadt.bsky.social (Gingerbread) - N/A followers
# - @lesclaudius.bsky.social (Sans nom) - N/A followers
# - @jcsatanas.bsky.social (JC) - N/A followers
# - @jeancrifer.bsky.social (Sans nom) - N/A followers
# - @chacunsongrain.bsky.social (Chacun son grain. 🦔) - N/A followers
# - @cerceuil.bsky.social (Réflexions Pragmatiques 🤔🔻🐝φ🐢⏚🎼🎶) - N/A followers
# - @kupwa.bsky.social (Sans nom) - N/A followers
# - @levigilant.bsky.social (Citoyen du Monde 🌍☮️☯️🌎) - N/A followers
# - @pouic.bsky.social (Pouic) - N/A followers
# - @trucsenserie.bsky.social (Monsieur B) - N/A followers
# - @zazadec.bsky.social (Sans nom) - N/A followers
# - @kriskroute.bsky.social (Sans nom) - N/A followers
# - @artegouchy.bsky.social (Aggro les fachos) - N/A followers
# - @marlenechinon.bsky.social (Marlène Chinon) - N/A followers
# - @quentin-rd.bsky.social (Quentin) - N/A followers
# - @apbboc.bsky.social (Sans nom) - N/A followers
# - @duboucher.eu (Serianox (Taylor's Version)) - N/A followers
# - @munierf.bsky.social (François Munier) - N/A followers
# - @jituba.bsky.social (JTB) - N/A followers
# - @moiohmax.bsky.social (Moiohmax) - N/A followers
# - @cesairebdc.bsky.social (Cesaire_BDC) - N/A followers
# - @morigan.bsky.social (𝗠origan Ƥendragoɳ 🐲) - N/A followers
# - @marcmeli01.bsky.social (Marc Meli) - N/A followers
# - @limonadenordic.bsky.social (Limonade nordique) - N/A followers
# - @manudream63.bsky.social (Sans nom) - N/A followers
# - @marmelade.bsky.social (Marme & lade 🌹) - N/A followers
# - @jusgra.bsky.social (Sans nom) - N/A followers
# - @lafilledelouest.bsky.social (La Fille de l'Ouest) - N/A followers
# - @exodelph.bsky.social (David Delph) - N/A followers
# - @simonriaux.fr (Simon Riaux) - N/A followers
# - @jesurlenet.bsky.social (Jesurlenet 🇺🇦🇬🇱🇪🇺) - N/A followers
# - @ecolokass.bsky.social (Sans nom) - N/A followers
# - @alex-b86.bsky.social (Sans nom) - N/A followers
# - @ritter-vomact.bsky.social (Ritter Vomact) - N/A followers
# - @ratchetco.bsky.social (Ratchetco) - N/A followers
# - @wolffcesarini.bsky.social (CesariniWolff) - N/A followers
# - @julien-apostat.bsky.social (Julien l'Apostat) - N/A followers
# - @melhoarfreilhec.bsky.social (Melhoar Freilhec 🎗️🏳️‍🌈🏳️‍⚧️🕊️🌳🌏) - N/A followers
# - @alinpiyaya.bsky.social (Alin Piyaya φ 🔻) - N/A followers
# - @maikie.bsky.social (Sans nom) - N/A followers
# - @psymad.bsky.social (Sans nom) - N/A followers
# - @francoispinchemel.bsky.social (François Pinchemel ) - N/A followers
# - @mongarsbruno.bsky.social (MonGarsBruno) - N/A followers
# - @colomban.bsky.social (Gilles Le Houézec) - N/A followers
# - @newtonmouloud.bsky.social (Newton Mouloud) - N/A followers
# - @xedoux.bsky.social (Xedoux) - N/A followers
# - @gibol1.bsky.social (Gibol1 - Brest) - N/A followers
# - @q9f.bsky.social (Q₉) - N/A followers
# - @recursiveaction.bsky.social (Eulbobo) - N/A followers
# - @sugaryin.bsky.social (a-yin) - N/A followers
# - @jing-chibi.bsky.social (Jing 🐸) - N/A followers
#
# --- RÉPONSES DIRECTES ---
# - De valmartinie.bsky.social: À lire sur l'Internationale fasciste qui soigne so...
# - De mampau.bsky.social: On a tous remarqué ça , ils font du commercial , i...
# - De bloublousky.bsky.social: Il commence à y avoir de la tension entre le servi...
# - De jackm22.bsky.social: J'ai essayé de voir sur LCI c'est carrément pro-fa...
# - De emilywolf.bsky.social: BFM dégoûté de ne pas pouvoir s'approcher alors qu...
# - De emilywolf.bsky.social: "on ne voit pas toute la manif et ils ont reçu des...
# - De disana.bsky.social: On ne doit pas regarder la même chaine???
# Moi j'en...
# - De marta38.bsky.social: Quel journaliste ? C'est tellement à contre couran...
# - De marlenechinon.bsky.social: C'est sûrement la dernière fois qu'on le voit à l'...
# - De huberthit.bsky.social: Dingue ! Il fait son travail !...

# %%
# Résumé concis des résultats
print("\n" + "="*50)
if post_uri:
    print("✓ RÉSUMÉ - Récupération terminée avec succès.")
else:
    print("✗ RÉSUMÉ - Échec de la récupération du post.")
print("="*50)
# Out:
# ==================================================
# ✓ RÉSUMÉ - Récupération terminée avec succès.
# ==================================================

# %%
# Inspecter la structure de la réponse get_reposted_by
print("\n=== DEBUG: Structure de la réponse get_reposted_by ===")
try:
    debug_response = client.app.bsky.feed.get_reposted_by({
        'uri': 'at://did:plc:jyszdkkd7q4ejj4mah36jgde/app.bsky.feed.post/3mfetst7zbc2z',
        'limit': 5
    })
    print(f"Type: {type(debug_response)}")
    print(f"Attributs: {dir(debug_response)}")
    print(f"Contenu: {debug_response}")
except Exception as e:
    print(f"Erreur: {e}")
# Out:
# === DEBUG: Structure de la réponse get_reposted_by ===
# Type: <class 'atproto_client.models.app.bsky.feed.get_reposted_by.Response'>
# Attributs: ['_ModelBase__alert_about_extra_fields', '__abstractmethods__', '__annotations__', '__class__', '__class_getitem__', '__class_vars__', '__copy__', '__deepcopy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__fields__', '__fields_set__', '__format__', '__ge__', '__get_pydantic_core_schema__', '__get_pydantic_json_schema__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__pretty__', '__private_attributes__', '__pydantic_complete__', '__pydantic_computed_fields__', '__pydantic_core_schema__', '__pydantic_custom_init__', '__pydantic_decorators__', '__pydantic_extra__', '__pydantic_fields__', '__pydantic_fields_set__', '__pydantic_generic_metadata__', '__pydantic_init_subclass__', '__pydantic_on_complete__', '__pydantic_parent_namespace__', '__pydantic_post_init__', '__pydantic_private__', '__pydantic_root_model__', '__pydantic_serializer__', '__pydantic_setattr_handlers__', '__pydantic_validator__', '__reduce__', '__reduce_ex__', '__replace__', '__repr__', '__repr_args__', '__repr_name__', '__repr_recursion__', '__repr_str__', '__rich_repr__', '__setattr__', '__setstate__', '__signature__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_calculate_keys', '_copy_and_set_values', '_get_value', '_iter', '_setattr_handler', 'cid', 'construct', 'copy', 'cursor', 'dict', 'from_orm', 'json', 'model_computed_fields', 'model_config', 'model_construct', 'model_copy', 'model_dump', 'model_dump_json', 'model_extra', 'model_fields', 'model_fields_set', 'model_json_schema', 'model_parametrized_name', 'model_post_init', 'model_rebuild', 'model_validate', 'model_validate_json', 'model_validate_strings', 'parse_file', 'parse_obj', 'parse_raw', 'reposted_by', 'schema', 'schema_json', 'update_forward_refs', 'uri', 'validate']
# Contenu: reposted_by=[ProfileView(did='did:plc:zdzrgpyfai3h4whw4ejapake', handle='vincureuil.bsky.social', associated=ProfileAssociated(activity_subscription=ProfileAssociatedActivitySubscription(allow_subscriptions='followers', py_type='app.bsky.actor.defs#profileAssociatedActivitySubscription'), chat=None, feedgens=None, labeler=None, lists=None, starter_packs=None, py_type='app.bsky.actor.defs#profileAssociated'), avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:zdzrgpyfai3h4whw4ejapake/bafkreifsfpf4gsj5utzfm6cpxt2drjlnybkihku7kfobja2qq7laut7mx4@jpeg', created_at='2024-11-24T17:11:03.845Z', debug=None, description='Écologie // Gauche radicale ', display_name='VincEcureuil', indexed_at='2024-11-24T23:30:32.446Z', labels=[], pronouns=None, status=None, verification=None, viewer=ViewerState(activity_subscription=None, blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following=None, known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileView'), ProfileView(did='did:plc:z6z5u3gm3xzinnp5taoemhn6', handle='muzahara3nour.bsky.social', associated=ProfileAssociated(activity_subscription=ProfileAssociatedActivitySubscription(allow_subscriptions='followers', py_type='app.bsky.actor.defs#profileAssociatedActivitySubscription'), chat=ProfileAssociatedChat(allow_incoming='following', py_type='app.bsky.actor.defs#profileAssociatedChat'), feedgens=None, labeler=None, lists=None, starter_packs=None, py_type='app.bsky.actor.defs#profileAssociated'), avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:z6z5u3gm3xzinnp5taoemhn6/bafkreih32bgoaar7ldrzbkov6mrkizqigecskk47vollbitqjgow6qechu@jpeg', created_at='2025-01-20T12:17:16.244Z', debug=None, description=None, display_name='', indexed_at='2026-01-18T10:22:41.524Z', labels=[], pronouns=None, status=None, verification=None, viewer=ViewerState(activity_subscription=None, blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following=None, known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileView'), ProfileView(did='did:plc:ykfbtvvvvvojgy7jrr77nbdo', handle='mikelkanik.bsky.social', associated=ProfileAssociated(activity_subscription=ProfileAssociatedActivitySubscription(allow_subscriptions='followers', py_type='app.bsky.actor.defs#profileAssociatedActivitySubscription'), chat=ProfileAssociatedChat(allow_incoming='all', py_type='app.bsky.actor.defs#profileAssociatedChat'), feedgens=None, labeler=None, lists=None, starter_packs=None, py_type='app.bsky.actor.defs#profileAssociated'), avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:ykfbtvvvvvojgy7jrr77nbdo/bafkreihmlr3m7fmibp7g755xh5ejbgfjgwv3b6qzoodowxwrof63s24ic4@jpeg', created_at='2023-08-10T23:08:29.776Z', debug=None, description='A guy with no talent\n\nWarning, presence of Nsfw materials| No minors allowed here 🔞\nAI/NFT/CRYPTO/PEDO/Far-rights & Troll = GET OUT! \n\nAvatar by @pof28.com', display_name='Mikel K.', indexed_at='2025-10-17T16:41:37.752Z', labels=[], pronouns=None, status=None, verification=None, viewer=ViewerState(activity_subscription=None, blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following=None, known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileView'), ProfileView(did='did:plc:y7ww3rn33diymvfillqk7a6x', handle='legrand1775.bsky.social', associated=ProfileAssociated(activity_subscription=ProfileAssociatedActivitySubscription(allow_subscriptions='followers', py_type='app.bsky.actor.defs#profileAssociatedActivitySubscription'), chat=None, feedgens=None, labeler=None, lists=None, starter_packs=None, py_type='app.bsky.actor.defs#profileAssociated'), avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:y7ww3rn33diymvfillqk7a6x/bafkreieun4rtmw224wz62jf3mrcsouehscapivv3oyfntw5gjhxjq37daa@jpeg', created_at= ...

# %%
# Convertir en dictionnaire pour voir la structure
try:
    debug_response = client.app.bsky.feed.get_reposted_by({
        'uri': 'at://did:plc:jyszdkkd7q4ejj4mah36jgde/app.bsky.feed.post/3mfetst7zbc2z',
        'limit': 3
    })
    
    # Convertir en dict
    if hasattr(debug_response, 'model_dump'):
        data = debug_response.model_dump()
        print(f"Clés: {list(data.keys())}")
    else:
        print(f"Type: {type(debug_response)}")
        print(f"First 200 chars: {str(debug_response)[:200]}")
            
except Exception as e:
    print(f"Erreur: {e}")
# Out:
# Clés: ['reposted_by', 'uri', 'cid', 'cursor']
